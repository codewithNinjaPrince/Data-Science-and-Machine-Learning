# %%
#  Scenario: AI‑Powered Email Assistant
# You’re building an email drafting assistant for a corporate team.
# - When a user starts typing:
# “Artificial Intelligence will…”
# - The assistant uses GPT‑2 to auto‑complete the sentence with a coherent continuation.
# - Example output:
# “Artificial Intelligence will transform the way businesses interact with customers,
# enabling faster decisions and personalized experiences.”

from transformers import pipeline

generator = pipeline("text-generation", model="gpt2")

print(generator("Artificial Intelligence will", max_length=30))
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Passing `generation_config` together with generation-related arguments=({'max_length'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=30) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': 'Artificial Intelligence will be a major force in today\'s industry.\n\nIt\'s not just AI that\'s changing the world. Artificial Intelligence is changing things—at least in the U.S. And so we\'re seeing it everywhere.\n\nI can\'t think of a better way to explain this. The first thing that comes to mind is that we\'re now seeing artificial intelligence, which is very much based on machine learning.\n\nThat\'s the next thing. That has been a big part of the business of our future.\n\nFor instance, when you start getting into AI, you\'re more likely to get a lot of new products.\n\nRight. And so that\'s why the business of AI is so important.\n\nFor example, a lot of people are starting to think, "Well, now this is going to be the next big thing."\n\nI\'m really excited to see what that will look like.\n\nSome of these changes are going to be really big.\n\nI\'m excited to see how they\'re going to be implemented.\n\nSo the next big thing that we\'ve been seeing is AI will probably change everything.\n\nAnd that\'s not just just AI, but also other things like machine learning.\n\nAll kinds'}]

# %%
#  Scenario: Game Storyline Generator
# You’re designing a fantasy role‑playing game and need quick ideas for quests and dialogue.
# - The developer types a prompt:
# “The hero enters the ancient forest and discovers…”
# - The GPT‑2 pipeline continues the story:
# “The hero enters the ancient forest and discovers a hidden village where the people whisper of
#  a cursed artifact buried beneath the old ruins.”

from transformers import pipeline

# GPT-2 text generation pipeline
generator = pipeline(
    "text-generation",
    model="gpt2"
)


print("Game Storyline Generator (type 0 to stop)\n")


while True:

    prompt = input("Enter your line: ")

    if prompt == "0":
        break

    result = generator(
        prompt,
        max_length=80,
        num_return_sequences=1,
        temperature=0.9,
    )

    print("\nStory:")
    print(result[0]["generated_text"])
    print()
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Game Storyline Generator (type 0 to stop)
#
# Enter your line: The hero enters the ancient forest and discovers a hidden village where the people whisper of a cursed artifact buried beneath the old ruins.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=80) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Story:
# The hero enters the ancient forest and discovers a hidden village where the people whisper of a cursed artifact buried beneath the old ruins. The villagers decide to make the discovery an act of self-sacrifice when a young woman comes to collect the artifacts herself. However, it soon becomes apparent that it is all in vain. The three must find the last artifact of their lives and bring it home. The villagers eventually find a living child hidden in a tree hidden by a forest path. The boy will soon enter the village, but they must find the lost artifact before it is forever lost all over again.
#
# Bunji and his family continue to search for the artifact, which is now hidden under the trees. It will never be found, but when the two find the treasure it will be stolen and the family will have to hunt all over again to retrieve it.
#
# Danganronpa Online 3 (PS3, PS Vita)
#
# The game was developed as a DLC, but is playable at the same time as the PS1 version.
#
# There are two modes in this game: Normal and Ultimate.
#
# Normal Mode
#
# The game starts off as normal with the protagonist in a small village. Once there the protagonist is immediately recruited and told to go to a room where they can see a statue in the distance. Upon entering the room everyone stops, but then the NPC standing
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_640/294720112.py in <cell line: 0>()
#      21 while True:
#      22
# ---> 23     prompt = input("Enter your line: ")
#      24
#      25     if prompt == "0":
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
# Scenario: Research Assistant for Academic Papers
# Imagine you’re building a tool for university researchers who analyze large collections of academic papers.
# - A researcher uploads a sentence:
# “Deep learning models are powerful”
# - Your system uses the BERT tokenizer to break the sentence into smaller units (tokens).

from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")

text = "Deep learning models are powerful"

tokens = tokenizer.tokenize(text)

print(tokens)
# Out:
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# ['deep', 'learning', 'models', 'are', 'powerful']

# %%
# 🏥 Scenario: Healthcare Chatbot for Patient Queries
# A hospital is developing a chatbot to help patients ask questions about their health.
# - A patient types:
# “Deep learning models are powerful” (or in practice, something like “I have chest pain and shortness of breath”).
# - The chatbot uses the BERT tokenizer to break the sentence into tokens:

from transformers import BertTokenizer

# Load BERT tokenizer
tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")


print("Healthcare Chatbot (type 0 to stop)\n")


while True:

    text = input("Patient: ")

    if text == "0":
        break

    # Tokenize sentence
    tokens = tokenizer.tokenize(text)

    # Convert to ids
    token_ids = tokenizer.convert_tokens_to_ids(tokens)

    print("\nTokens:")
    print(tokens)

    print("\nToken IDs:")
    print(token_ids)

    print()
# Out:
# Healthcare Chatbot (type 0 to stop)
#
# Patient: Fever and cough
#
# Tokens:
# ['fever', 'and', 'cough']
#
# Token IDs:
# [9016, 1998, 19340]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_640/1407953852.py in <cell line: 0>()
#      16 while True:
#      17
# ---> 18     text = input("Patient: ")
#      19
#      20     if text == "0":
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# -> 1219                 raise KeyboardInterrupt("Interrupted by user") from None
#    1220             except Exception:
#    1221                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
# Scenario: Exploring Creativity in AI Writing
# A university professor is running a workshop on creative writing with AI.
# - The professor gives students the prompt:
# “The future of Artificial Intelligence”
# - The system uses GPT‑2 to generate continuations of the sentence.
# To demonstrate how temperature affects creativity:
# - With temperature = 0.2 (low randomness), the output is more predictable and conservative, e.g.:
# “The future of Artificial Intelligence will bring advancements in healthcare, education, and business.”

from transformers import pipeline

generator = pipeline("text-generation", model="gpt2")

prompt = "The future of Artificial Intelligence"

print(generator(prompt, max_length=40, temperature=0.2))
print(generator(prompt, max_length=40, temperature=0.8))
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': 'The future of Artificial Intelligence is in the hands of the next generation of AI.\n\nThe future of Artificial Intelligence is in the hands of the next generation of AI.\n\nThe future of Artificial Intelligence is in the hands of the next generation of AI.\n\nThe future of Artificial Intelligence is in the hands of the next generation of AI.\n\nThe future of Artificial Intelligence is in the hands of the next generation of AI.\n\nThe future of Artificial Intelligence is in the hands of the next generation of AI.\n\nThe future of Artificial Intelligence is in the hands of the next generation of AI.\n\nThe future of Artificial Intelligence is in the hands of the next generation of AI.\n\nThe future of Artificial Intelligence is in the hands of the next generation of AI.\n\nThe future of Artificial Intelligence is in the hands of the next generation of AI.\n\nThe future of Artificial Intelligence is in the hands of the next generation of AI.\n\nThe future of Artificial Intelligence is in the hands of the next generation of AI.\n\nThe future of Artificial Intelligence is in the hands of the next generation of AI.\n\nThe future of Artificial Intelligence is in the hands of the next generation of AI.\n\nThe future of Artificial Intelligence is in the hands'}]
# [{'generated_text': 'The future of Artificial Intelligence is in the spotlight, and with it comes a number of new technologies that will allow us to do a lot more than just work. Here is a summary of some of the most exciting developments that have been brought to light.\n\n• Intelligent, distributed computation and machine learning (ML&M) are now almost ready to be deployed and implemented.\n\n• Artificial Intelligence is a growing discipline.\n\n• In 2014, five artificial intelligence companies came within a quarter of the US market for AI software at the highest level.\n\n• AI is increasingly embedded in our lives.\n\n• The rise of online gaming is changing the way we interact with information, and allowing us to be involved in a richer, more personalized world.\n\n• A more user friendly and more open web is an exciting and exciting world for all of us.\n\n• The internet has the potential to revolutionize the way we interact with information.\n\n• AI is transforming commerce.\n\n• The future of information is in the eye of the beholder.\n\n• Artificial intelligence is a good thing.\n\n• Iain Banks: "I think AI is already a thing. I just don\'t think it\'s really what we need. I think it\'s what we'}]

# %%
#  Scenario: Scriptwriting Assistant for Film Production
# A film studio is experimenting with AI to help writers brainstorm dialogue and plot ideas.
# - The writer provides the prompt:
# “The future of Artificial Intelligence”
# - The system generates two versions of the continuation:
# - Temperature = 0.2 (low randomness)
# Output is more predictable and formal, e.g.:
# “The future of Artificial Intelligence will improve industries, enhance productivity, and reshape education.”
# → This is useful for serious, factual narration in a documentary script.
# - Temperature = 0.8 (higher randomness)
# Output is more imaginative and varied, e.g.:
# “The future of Artificial Intelligence dances with uncertainty, weaving stories of machines dreaming and societies reborn.”
# → This is perfect for creative dialogue or speculative sci‑fi storytelling

from transformers import pipeline

# Load text generation pipeline (GPT-2)
generator = pipeline(
    "text-generation",
    model="gpt2"
)

prompt = "The future of Artificial Intelligence"


# Low temperature (predictable)
low_temp = generator(
    prompt,
    max_length=40,
    temperature=0.2,
    num_return_sequences=1
)


# High temperature (creative)
high_temp = generator(
    prompt,
    max_length=40,
    temperature=0.8,
    num_return_sequences=1
)


print("Prompt:")
print(prompt)


print("\nTemperature = 0.2 (formal output)")
print(low_temp[0]["generated_text"])


print("\nTemperature = 0.8 (creative output)")
print(high_temp[0]["generated_text"])
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Prompt:
# The future of Artificial Intelligence
#
# Temperature = 0.2 (formal output)
# The future of Artificial Intelligence
#
# In the next few years, we will see a lot of new technologies that will make it possible to create intelligent machines. We will see that the human brain is the most powerful machine on the planet, and that it will be able to learn from our own experiences. We will see that the human brain is the most powerful machine on the planet, and that it will be able to learn from our own experiences.
#
# We will see that the human brain is the most powerful machine on the planet, and that it will be able to learn from our own experiences. We will see that the human brain is the most powerful machine on the planet, and that it will be able to learn from our own experiences. We will see that the human brain is the most powerful machine on the planet, and that it will be able to learn from our own experiences. We will see that the human brain is the most powerful machine on the planet, and that it will be able to learn from our own experiences. We will see that the human brain is the most powerful machine on the planet, and that it will be able to learn from our own experiences. We will see that the human brain is the most powerful machine on the planet, and that it will be able to learn from
#
# Temperature = 0.8 (creative output)
# The future of Artificial Intelligence could include "enhanced intelligence," a field that has been described as "a science fiction thing to happen."
#
# It's unclear whether the future of artificial intelligence is in that category, or whether AI will actually become more powerful than humans in the future.
#
# In 2013, Google announced it would be developing a neural network to process images and text information as it searches for clues on the internet, creating a "deep learning model that learns the most logical conclusions from many known information sources."
#
# In recent years, researchers have been investigating how artificial intelligence has already been used to solve problems in neuroscience, psychology, and more.
#
# Earlier this year, the European Commission announced that it plans to use its €4 billion (€5 billion) project to improve the processing speed of machine learning, which is used to model complex tasks.
#
# But scientists and some analysts question whether the future of artificial intelligence will be as simple as it seems to others.
#
# "This is about the first time that we are looking at a future in which intelligence is not limited to neural networks," said Cirof Toretto, a professor at the University of Copenhagen.
#
# "It is also possible that the future of AI could be the ability to process information in such

# %%
# Scenario: AI‑Powered News Headline Generator
# A digital media company wants to help journalists brainstorm headlines and opening lines for articles.
# - The system asks the journalist to enter a prompt (e.g., “Enter a prompt: The future of Artificial Intelligence”).
# - The GPT‑2 model then generates a continuation of the text, up to 50 tokens.
# - Example output:
# “The future of Artificial Intelligence will reshape industries, redefine creativity, and challenge
#  our understanding of human potential.”

from transformers import pipeline

generator = pipeline("text-generation", model="gpt2")

prompt = input("Enter a prompt: ")

output = generator(prompt, max_length=50)

print(output[0]["generated_text"])
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Enter a prompt: The future of Artificial Intelligence will reshape industries, redefine creativity, and challenge #  our understanding of human potential.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# The future of Artificial Intelligence will reshape industries, redefine creativity, and challenge #  our understanding of human potential.
#
# The Future of Artificial Intelligence will reshape industries, redefine creativity, and challenge # our understanding of human potential.
#
# We are now in the midst of a revolution in how we interact with the world in a way that is both intuitive and easy to understand.
#
# We're the first to see the potential of AI for the creative and creative industries.
#
# We are the first to see the potential of AI for the creative and creative industries.
#
# We're the first to see the potential of AI for the creative and creative industries.
#
# I'm excited about the future of AI, and I'm excited about the future of AI
#
# I'm excited about the future of AI
#
# I'm excited about the future of AI
#
# I'm excited about the future of AI
#
# I want to make sure that AI is used and used well
#
# I'd like to make sure that AI is used and used well
#
# I'd like to make sure that AI is used and used well
#
# There are a lot of people who believe that AI is the future of life. They believe that it's a "better" than human life.
#
# But people like me have a different view. I believe that AI is the future of

# %%
# 🎓 Scenario: Student Brainstorming Tool for Essay Writing
# A college student is struggling to start their essay.
# - The system prompts them:
# “Enter a prompt:”
# - The student types:
# “The impact of technology on education”
# - The GPT‑2 model generates a continuation up to 50 tokens, for example:
# “The impact of technology on education has transformed classrooms, enabling online learning,
# personalized study plans, and global collaboration among students.”

from transformers import pipeline

# Load GPT-2 model for text generation
generator = pipeline("text-generation", model="gpt2")

# Ask student for essay topic
prompt = input("Enter a prompt: ")

# Generate continuation (up to 50 tokens)
output = generator(prompt, max_length=50)

# Print generated essay idea
print("\nGenerated Idea:")
print(output[0]["generated_text"])
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Enter a prompt: The impact of technology on education has transformed classrooms, enabling online learning, personalized study plans, and global collaboration among students.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Generated Idea:
# The impact of technology on education has transformed classrooms, enabling online learning, personalized study plans, and global collaboration among students.
#
# The latest changes to the SAT and ACT are significant and impact on the quality of students who take the tests. As a result, the SAT and ACT are becoming less popular and the ACT is now more popular among students. It is estimated that one in six students in the U.S. is currently enrolled in a test in the ACT.
#
# The ACT has become a major subject for research and public education. The SAT and ACT are the most popular subjects in the United States, with 1 in 6 students taking the test. The SAT and ACT are the most popular subjects in the United States, with 1 in 6 students taking the test.
#
# As an example, when the SAT and ACT were introduced in the 1990s, most of the students who took the SAT or ACT were from low to middle income families. Today, nearly two-thirds of all students currently take the test. The number of students who are enrolled in the SAT or ACT is projected to rise from 1.2 million in 2000 to 2.2 million in 2050.
#
# The U.S. Department of Education (DoE) has estimated that the SAT and ACT are among the most popular subjects in the United States. The SAT and ACT are the most popular subjects in the United

# %%
# Scenario: AI Model Evaluation in a Startup
# A startup is building an AI‑powered content assistant to help marketers draft product descriptions.
# - The team wants to compare two models: GPT‑2 (larger, more expressive) and DistilGPT‑2 (smaller, faster, distilled version).
# - They use the same prompt:
# “Artificial Intelligence will transform”
# - The system generates two outputs:
# - GPT‑2 Output
# Longer, more detailed continuation, e.g.:
# “Artificial Intelligence will transform industries by automating processes, enhancing creativity, and
# reshaping how humans interact with technology.”
# → Richer but slower to run.
# - DistilGPT‑2 Output


from transformers import pipeline

gpt2 = pipeline("text-generation", model="gpt2")
distilgpt2 = pipeline("text-generation", model="distilgpt2")

prompt = "Artificial Intelligence will transform"

print("GPT2:", gpt2(prompt, max_length=40))
print("DistilGPT2:", distilgpt2(prompt, max_length=40))
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# config.json:   0%|          | 0.00/762 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/353M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/76 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: distilgpt2
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# transformer.h.{0, 1, 2, 3, 4, 5}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=40) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# GPT2: [{'generated_text': 'Artificial Intelligence will transform the way we think about technology and how we interact with it. In this post we will cover the three major facets of Artificial Intelligence: The Big Data Era, the Deep Web, and the Deep Web.\n\nHow to Build a Business Model with Artificial Intelligence\n\nLet\'s start with the Big Data Era. The big data era is the era of massive data collection. It is characterized as our "big data" era and was the golden era of human creativity. We now know that it is possible to build a business model for a large scale data collection. In fact, I think we can do a lot better than we have ever done before. The Big Data Era has been so successful that it has become one of the most popular industries in the world.\n\nThe Big Data Era is a time of great change in the way we think about technology and how we interact with it. The Big Data Era has been so successful that it has become one of the most popular industries in the world. There are many different ways in which companies can build a business model based on the Big Data Era. The most common ways are through software development, cloud computing, and data analytics.\n\nThe Big Data Era is a time of great change in the way we think about technology'}]
# DistilGPT2: [{'generated_text': 'Artificial Intelligence will transform a world that is already inhabited by artificial intelligence in the near future.\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n'}]

# %%
# Scenario: Educational Tool for Classroom Learning
# A high school teacher is introducing students to AI‑powered writing assistants.
# - The teacher wants to show how different models produce different styles of text.
# - They use the same prompt:
# “Artificial Intelligence will transform”
# - The system generates two outputs:
# - GPT‑2 Output
# More elaborate continuation, e.g.:
# “Artificial Intelligence will transform the way societies function, influencing education, healthcare, and the future of human creativity.”
# → Great for showing students how AI can generate rich, detailed ideas.
# - DistilGPT‑2 Output
# Shorter, faster continuation, e.g.:
# “Artificial Intelligence will transform our daily lives.”
# → Useful for demonstrating concise summaries.

from transformers import pipeline

# Load models
gpt2 = pipeline("text-generation", model="gpt2")
distilgpt2 = pipeline("text-generation", model="distilgpt2")

prompt = "Artificial Intelligence will transform"

# Generate text
print("GPT-2 Output:")
print(gpt2(prompt, max_length=30)[0]['generated_text'])

print("\nDistilGPT-2 Output:")
print(distilgpt2(prompt, max_length=30)[0]['generated_text'])
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Loading weights:   0%|          | 0/76 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: distilgpt2
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# transformer.h.{0, 1, 2, 3, 4, 5}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=30) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# GPT-2 Output:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=30) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Artificial Intelligence will transform the way people interact with computers.
#
# The first step is to make the computers smarter.
#
# "We will use artificial intelligence to create the next generation of social robots and machines," he said.
#
# An artificial intelligence will help social network users see other people as they interact with them.
#
# At the same time, he said, AI will be able to predict what people will say, but never to know what they will say.
#
# "We will be able to do this with other people's actions," he said.
#
# "We will also be able to make people think more carefully."
#
# The research team said the system will help social networks to better manage their users' behaviour.
#
# "It will help them to find the best ways to interact with each other, to find the right way to interact with each other," said the researchers.
#
# "We will be able to learn what is important to each other and what is important to them."
#
# Topics: artificial-intelligence-and-social-intelligences, computers---programming, artificial-intelligence, artificial-intelligence, human-computer-science, internet-technology, nsw, australia
#
# First posted
#
# DistilGPT-2 Output:
# Artificial Intelligence will transform the world of technology, including the Internet. Today, the United States, Russia, and China are working toward a future where AI will be able to manage the world's digital economy through the Internet.
#
#
#
#
# The goal is to have a single computer capable of managing the world's digital economy by 2020, and by 2030, the United States will have the capability to manage the world's digital economy by 2025.
# The goal is to have a single computer capable of managing the world's digital economy by 2030, and by 2030, the United States will have the capability to manage the world's digital economy by 2023, with both of these goals being achieved.
# The goal is to have a single computer capable of managing the world's digital economy by 2023, with both of these goals being achieved.
# The goal is to have a single computer capable of managing the world's digital economy by 2023, with both of these goals being achieved.
# As a result, the goal will be to have a single computer capable of managing the world's digital economy by 2023, with both of these goals being achieved.
# The goal is to have a single computer capable of managing the world's digital economy by 2023, with both of these goals being achieved.

# %%
import spacy

# Load English model
nlp = spacy.load("en_core_web_sm")


text = """
Manchester United defeated Real Madrid 3-2 at Wembley Stadium, London.
Cristiano Ronaldo scored twice, while Marcus Rashford netted the winning goal in July 2024.
"""


doc = nlp(text)


print("Named Entities:\n")

for ent in doc.ents:
    print(ent.text, "->", ent.label_)
# Out:
# Named Entities:
#
# Manchester United -> PERSON
# Wembley Stadium -> GPE
# London -> GPE
# Cristiano Ronaldo -> PERSON
# Marcus Rashford -> PERSON
# July 2024 -> DATE

# %%
# 📘 Scenario: Smart Manufacturing Insights
# Context:
# You are part of a data science team in a smart manufacturing company. Your manager wants you to explore how different
# technical concepts (like maintenance, telemetry, quality control, supply chain) are related in company documents.
# By training a small Word2Vec model, you can uncover semantic similarities between words and measure how closely they are
#  connected. This helps in building recommendation systems, knowledge graphs, or even automated reporting tools.
# Task:
# Given a short corpus describing manufacturing operations, train a Word2Vec model and analyze word similarities.

# !pip install gensim nltk

# Word embeddings with gensim Word2Vec
# Setup: python -m pip install gensim nltk
from gensim.models import Word2Vec
import nltk
from nltk.tokenize import word_tokenize

nltk.download("punkt_tab")


# Corpus (manufacturing documents)

corpus = [
    "predictive maintenance improves machine performance",
    "telemetry data helps monitor equipment health",
    "quality control ensures product reliability",
    "supply chain management tracks materials",
    "maintenance teams analyze telemetry reports",
    "quality inspection detects defects early",
    "smart manufacturing uses automation and sensors",
    "supply chain delays affect production",
]


# Tokenize sentences

tokenized = [word_tokenize(sentence.lower()) for sentence in corpus]


# Train Word2Vec model

model = Word2Vec(
    sentences=tokenized,
    vector_size=50,
    window=3,
    min_count=1,
    workers=2
)


# Check similarity

print("Similarity between maintenance and telemetry:")
print(model.wv.similarity("maintenance", "telemetry"))


print("\nWords similar to quality:")
print(model.wv.most_similar("quality"))


print("\nWords similar to supply:")
print(model.wv.most_similar("supply"))
# Out:
# Requirement already satisfied: gensim in /usr/local/lib/python3.12/dist-packages (4.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.12/dist-packages (3.9.1)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.12/dist-packages (from gensim) (2.0.2)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from gensim) (1.16.3)
# Requirement already satisfied: smart_open>=1.8.1 in /usr/local/lib/python3.12/dist-packages (from gensim) (7.5.1)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from nltk) (8.3.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.12/dist-packages (from nltk) (2025.11.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from nltk) (4.67.3)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.12/dist-packages (from smart_open>=1.8.1->gensim) (2.1.2)
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# Similarity between maintenance and telemetry:
# -0.20599009
#
# Words similar to quality:
# [('predictive', 0.2507197856903076), ('improves', 0.24833160638809204), ('reports', 0.19598904252052307), ('maintenance', 0.16564857959747314), ('uses', 0.1552513837814331), ('defects', 0.1439756155014038), ('management', 0.14380484819412231), ('ensures', 0.14334970712661743), ('sensors', 0.1395133137702942), ('helps', 0.12948276102542877)]
#
# Words similar to supply:
# [('monitor', 0.37564846873283386), ('detects', 0.22947187721729279), ('health', 0.22093552350997925), ('product', 0.2195691019296646), ('performance', 0.19483275711536407), ('analyze', 0.1607116162776947), ('reports', 0.14868542551994324), ('maintenance', 0.12485211342573166), ('data', 0.11035431176424026), ('helps', 0.09328743815422058)]

# %%
# 📘 Scenario: Healthcare Research Insights
# Context:
# You are part of a data science team in a healthcare research institute. Your manager wants you to analyze medical reports and research papers to explore how different technical concepts (like diagnosis, treatment, symptoms, patients, medication) are related. By training a small Word2Vec model, you can uncover semantic similarities between words and measure how closely they are connected. This helps in building clinical decision support systems, medical knowledge graphs, or even automated literature reviews.
# Task:
# Given a short corpus describing healthcare operations, train a Word2Vec model and analyze word similarities.

from gensim.models import Word2Vec
import nltk
from nltk.tokenize import word_tokenize

nltk.download("punkt")


# Healthcare corpus

corpus = [
    "doctors diagnose patients using symptoms",
    "treatment includes medication and therapy",
    "patients receive treatment after diagnosis",
    "symptoms help doctors identify disease",
    "medication reduces pain and infection",
    "clinical research studies new treatment methods",
    "patients respond differently to medication",
    "early diagnosis improves treatment success",
]


# Tokenize

tokenized = [word_tokenize(sentence.lower()) for sentence in corpus]


# Train Word2Vec model

model = Word2Vec(
    sentences=tokenized,
    vector_size=50,
    window=3,
    min_count=1,
    workers=2
)


# Similarity check

print("Similarity between diagnosis and treatment:")
print(model.wv.similarity("diagnosis", "treatment"))


print("\nWords similar to symptoms:")
print(model.wv.most_similar("symptoms"))


print("\nWords similar to patients:")
print(model.wv.most_similar("patients"))
# Out:
# Similarity between diagnosis and treatment:
# -0.0144468425
#
# Words similar to symptoms:
# [('methods', 0.3067283034324646), ('clinical', 0.2706151604652405), ('early', 0.2244037389755249), ('receive', 0.21430064737796783), ('help', 0.20489609241485596), ('differently', 0.19778774678707123), ('doctors', 0.18339447677135468), ('and', 0.10229138284921646), ('respond', 0.10173003375530243), ('new', 0.08190789073705673)]
#
# Words similar to patients:
# [('infection', 0.19609762728214264), ('and', 0.16568750143051147), ('differently', 0.15528690814971924), ('studies', 0.1438439041376114), ('help', 0.14382122457027435), ('therapy', 0.14335165917873383), ('improves', 0.13940715789794922), ('treatment', 0.12673203647136688), ('using', 0.12509940564632416), ('to', 0.12116614729166031)]
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# Scenario-Based Assessment
# Case Study: AI Assistant for a University Helpdesk

# A large university receives thousands of student queries daily related to admissions, fees, hostel facilities, course
#  schedules, and exam results.

# Currently, these queries are answered manually by staff, causing:

# Slow response time

# High operational cost

# Inconsistent responses

# The university plans to develop an AI-powered chatbot using Generative AI and Large Language Models (LLMs) to
#  automatically respond to student questions.

# You are part of the AI consulting team tasked with designing the solution.

# ==========================================
# UNIVERSITY AI HELPDESK CHATBOT
# Demonstrates:
# Generative AI
# Large Language Models (LLMs)
# Tokenization
# Transformer Inference
# Prompt Engineering
# ==========================================

# Install required libraries first
# pip install transformers torch

# STEP 3: Define University Knowledge Base
# # ------------------------------------------
# knowledge_base = """
# University Helpdesk Information

# Hostel Admission Requirements:
# - Admission confirmation letter
# - Government ID proof
# - Two passport size photographs

# Course Registration:
# - Registration happens online through the university portal
# - Students must register before the semester deadline

# Fee Payment:
# - Fees can be paid through the student dashboard
# - Online payment methods include debit card, credit card, and net banking

# Examination Schedule:
# - Semester exams usually start in December and May

# Library Access:
# - Students must carry their university ID card
# """

from transformers import pipeline

# Load GPT-2 model (free)
generator = pipeline(
    "text-generation",
    model="gpt2"
)


# Knowledge Base

knowledge_base = """
University Helpdesk Information

Hostel Admission Requirements:
- Admission confirmation letter
- Government ID proof
- Two passport size photographs

Course Registration:
- Registration happens online through the university portal
- Students must register before the semester deadline

Fee Payment:
- Fees can be paid through the student dashboard
- Online payment methods include debit card, credit card, and net banking

Examination Schedule:
- Semester exams usually start in December and May

Library Access:
- Students must carry their university ID card
"""


print("🎓 University Helpdesk Chatbot (GPT-2)")
print("Type 'exit' to stop\n")


while True:

    question = input("Student: ")

    if question.lower() == "exit":
        print("Chatbot: Goodbye!")
        break


    prompt = f"""
You are a helpful university helpdesk assistant.

Use the information below to answer the question.

{knowledge_base}

Question: {question}

Answer:
"""


    result = generator(
        prompt,
        max_length=200,
        temperature=0.4,
        num_return_sequences=1
    )


    text = result[0]["generated_text"]

    # show only generated answer part
    answer = text[len(prompt):]

    print("\nChatbot:", answer.strip())
    print()
# Out:
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# 🎓 University Helpdesk Chatbot (GPT-2)
# Type 'exit' to stop
#
# Student: what is university offers
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=200) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Chatbot: - University offers a variety of courses including:
#
# - Business, Business Research, Business Education, Business Management, Business Management, Business Management, Business Management, Business Management, Business Management, Business Management, Business Management, Business Management, Business Management, Business Management, Business Management, Business Management, Business Management, Business Management, Business Management, Business Management, Business Management, Business Management, Business Management, Business Management, Business Management, Business Management, Business Management, Business Management, Business Management, Business Management, Business Management, Business Management, Business Management, Business Management, Business Management, Business Management, Business Management, Business Management, Business Management, Business Management, Business Management, Business Management, Business Management, Business Management, Business Management, Business Management, Business Management, Business Management, Business Management, Business Management, Business Management, Business Management, Business Management, Business Management, Business Management, Business Management, Business Management, Business Management, Business Management, Business Management, Business Management, Business Management, Business Management, Business Management, Business Management, Business Management, Business Management, Business Management, Business Management, Business Management, Business Management, Business Management, Business Management, Business Management, Business Management, Business Management, Business Management, Business Management, Business Management, Business Management, Business Management, Business
