# %%
import matplotlib.pyplot as plt

months=["Jan","Feb","Mar","Apr"]
sales=[10000,12000,15000,13000]

plt.plot(months, sales)
plt.title("Monthly sales Trend")
plt.xlabel("Month")
plt.ylabel("Sales")
plt.show()

# %%
# Here’s a different context scenario question using your line chart idea, but instead of sales, let’s make it
# about student attendance:

# 📘 Scenario Question
# A college is tracking student attendance across the first four months of the semester:
# - January: 85 students present on average
# - February: 90 students
# - March: 95 students
# - April: 88 students
# The academic coordinator wants to visualize the attendance trend to see whether students are attending classes more regularly or
#  if there are fluctuations.
# You are asked to:
# - Plot a line chart showing the monthly attendance trend.
# - Label the axes and add a title to make the chart clear.
# - Interpret the chart:
# - Which month had the highest attendance?
# - Did attendance steadily increase, or were there ups and downs?
# - What might explain the dip in April?
months=["Jan","Feb","March","April"]
attendance=[85,90,95,88]

plt.plot(months,attendance) # For line chart
plt.title("Students Percentage")
plt.xlabel("Months")
plt.ylabel("Attendance percentage")
plt.show()

# %%
regions=["North","East","South","West"]
revenue=[20000,15000,18000,22000]

plt.bar(regions,revenue,color="red")
plt.title("Revenue by Region")
plt.show()

# %%
# 📘 Scenario Question
# A university library tracked the number of books checked out from four sections during the last semester:
# - North Wing: 2,000 books
# - South Wing: 1,500 books
# - East Wing: 1,800 books
# - West Wing: 2,200 books
# The librarian wants to compare which section had the highest activity and which section had the lowest.
# You are asked to:
# - Plot a bar chart showing the number of books checked out by section.
# - Add a title and axis labels to make the chart clear.
# - Interpret the chart:
# - Which section had the highest checkouts?
# - Which section had the lowest?
# - What insights could the librarian use to improve resource allocation?
Wings=["North","South","East","West"]
Books=[2000,1500,1800,2200]
colors=["red","green","blue","yellow"]
plt.bar(Wings,Books,color=colors)
plt.title("Books Checked Out")
plt.xlabel("Wings")
plt.ylabel("Books")
plt.show()

# %%
#📘 Scenario Question
# A company surveyed the salaries of 1,000 employees. The average salary was around $50,000, with most employees earning
#  within a spread of about $10,000.
# The HR department wants to visualize the distribution of salaries to understand pay structure and
#  identify whether salaries are
#  clustered around the average or spread out widely.
# You are asked to:
# - Plot a histogram showing the salary distribution.
# - Add a title to make the chart clear.
# - Interpret the chart:
# - What does the shape of the distribution suggest about how salaries are spread?
# - Are most employees earning close to the average, or is there a wide variation?
# - How could HR use this information to review compensation policies?
import numpy as np
salaries=np.random.normal(50000,10000,1000) # 50000=median salaries, 10000=variation, 1000=employees
plt.hist(salaries,bins=20)
plt.title("Salary Distribution")
plt.show()

# %%
# 📘 Scenario Question
# A professor recorded the exam scores of 1,000 students in a statistics course. The average
# score was around 75 marks, with most
# students scoring within a spread of about 10 marks.
# The professor wants to visualize the distribution of exam scores to understand how students
#  performed overall and
#  whether the scores follow a normal pattern.
# You are asked to:
# - Plot a histogram showing the distribution of exam scores.
# - Add a title and axis labels to make the chart clear.
# - Interpret the chart:
# - What does the shape of the distribution suggest about student performance?
# - Are most students clustered around the average, or is there wide variation?
# - How could the professor use this information to adjust teaching methods?

# Generate scores (Normal Distribution)
scores = np.random.normal(75, 10, 1000)

# Plot Histogram
plt.hist(scores, bins=15, color="pink", edgecolor="black")

# Add title and labels
plt.title("Distribution of Exam Scores")
plt.xlabel("Scores")
plt.ylabel("Number of Students")

plt.show()

# %%
# Create a figure and axis object with size 8x5 inches
fig,ax = plt.subplots(figsize=(8,5))

# Sample data - monthly sales revenue
months = ['Jan','Feb','Mar','Apr','May','Jun']
sales = [42000,55000,49000,67000,71000,83000]

# Plot a line graph
# color = line color
# linewidth = thickness of line
# marker = circle points on each data value
# markersize = size of markers
ax.plot(months, sales, color="#008408", linewidth=2.5, marker='o', markersize=7)

# Set chart title
ax.set_title("Monthly Sales 2024", fontsize=14)

# Set X-axis label
ax.set_xlabel("Months", fontsize=12)

# Set Y-axis label
ax.set_ylabel("Revenue", fontsize=12)

# Add grid lines only on Y-axis
ax.grid(axis='y', alpha=0.4)

# Adjust layout to prevent overlapping
plt.tight_layout()

plt.show()

# %%
# 📘 Scenario Question
# A company wants to analyze whether advertising spend impacts sales revenue. The marketing team collected data from
#  several campaigns, where ad spend ranged from $2,000 to $18,000 and the corresponding sales revenue was recorded.
# You are asked to:
# - Plot a scatter chart showing the relationship between ad spend and sales.
# - Add a trend line to highlight the overall pattern.
# - Interpret the chart: does higher ad spend generally lead to higher sales?

# Data: Ad spends vs Sales
ad_spend=np.array([2000,4000,6000,8000,10000,12000,14000,16000,18000])
sales=np.array([7000,15000,21000,25000,32000,36000,42000,47000,52000])

#Scatter plot
# Each blue dot represents one observation:
# X-axis = Ad Spend
# Y-axis = Sales
plt.scatter(ad_spend,sales,color='blue',alpha=0.7)

#Trend line
# np.polyfit(x, y, 1)
# 1 → degree of polynomial (1 means straight line)
# It calculates slope (m) and intercept (b) for equation: y = mx + b
z=np.polyfit(ad_spend,sales,1)

# Convert coefficients into a mathematical function
p=np.poly1d(z)
# Plot the regression line
# "r--" means red dashed line
plt.plot(ad_spend,p(ad_spend),"r--",label='Trend')

#Labels and title
plt.xlabel('Ad Spend')
plt.ylabel('Sales')
plt.title('Ad Spend vs Sales')
plt.legend()
plt.show()

# %%
#Probability
import random
heads=0
total=1000
for i in range(total):
  result=random.randint(0,1)
  if result==1:
    heads=heads+1
tails=total-heads
print("Heads: " , heads)
print("Tails: ", tails)
print("P(Heads)=" ,heads/total)
# Out:
# Heads:  501
# Tails:  499
# P(Heads)= 0.501

# %%
#Distribution

#200 random heights, avg=165, spread=8
heights=np.random.normal(165,8,200)

print("Shortest:",round(heights.min(),1))
print("Tallest:",round(heights.max(),1))
print("Average:",round(heights.mean(),1))

#Draw the bell shape
plt.hist(heights,bins=20,
color="#00BFA6",
edgecolor="white")

plt.axvline(heights.mean(),color="red",linewidth=2,label='Average')

plt.title("Height of 200 students")
plt.xlabel("height centimeters")
plt.ylabel("No of students")
plt.legend()
plt.show()
# Out:
# Shortest: 146.0
# Tallest: 181.8
# Average: 165.1

# %%
from scipy.stats import binom
import matplotlib.pyplot as plt
import numpy as np

# Number of questions
n = 10

# Probability of getting one question correct
p = 0.25   # 1 out of 4 chance (corrected from 0.23)

# ----------------------------
# Probability Calculations
# ----------------------------

# P(Exactly 3 correct)
p3 = binom.pmf(3, n, p)
print("P(Exactly 3) =", round(p3, 3))

# P(At least 5 correct)
p5 = 1 - binom.cdf(4, n, p)
print("P(5 or more) =", round(p5, 3))

# ----------------------------
# Draw Bar Chart
# ----------------------------

# Possible number of correct answers (0 to 10)
k = np.arange(0, 11)

# Probability for each k
probabilities = binom.pmf(k, n, p)

# Plot
plt.bar(k, probabilities, color='#7B2EBF')

plt.xlabel("Number of Correct Answers")
plt.ylabel("Probability")
plt.title("Binomial Distribution (n=10, p=0.25)")

plt.show()
# Out:
# P(Exactly 3) = 0.25
# P(5 or more) = 0.078

# %%
#📘 Scenario Question
# A company surveyed the salaries of 1,000 employees. The average salary was around $50,000, with most employees earning
# within a spread of about $10,000.
# The HR department wants to visualize the distribution of salaries to understand pay structure and
# identify whether salaries are # clustered around the average or spread out widely. # You are asked to:
# - Plot a histogram showing the salary distribution.
# - Add a title to make the chart clear.
# - Interpret the chart:
# - What does the shape of the distribution suggest about how salaries are spread?
# - Are most employees earning close to the average, or is there a wide variation?
# - How could HR use this information to review compensation policies?

import matplotlib.pyplot as plt
import numpy as np

salaries=np.random.normal(50000,10000,1000)

#Plot Histogram
plt.hist(salaries, bins=20, color="skyblue", edgecolor="black")
plt.title("Distribution of Employee Salaries")
plt.xlabel("Salary ($)")
plt.ylabel("Number of Employees")
plt.show()

# %%
# Scenario: Corporate Employee Performance Dashboard A company tracks quarterly performance scores of employees across different departments.
# The HR analytics team wants to analyze this dataset to identify top performers, departmental trends, and highlight exceptional scores.
#Dataset The dataset contains the following columns: - Employee: Name of the employee - Department: Department they belong to (Sales, HR, IT, Finance, etc.)
# - Quarter: The quarter in which the performance score was recorded (Q1, Q2, Q3, Q4) - Score: Performance score (numeric value) Tasks - Filtering (Core Corporate Skill)
#- Find employees with Score > 90 (exceptional performers). - Filter records for the Sales department only. - Sorting (Power Moment) -
# Sort employees by Score in descending order to rank performance. - Sort by Department first, then Score to see departmental rankings. -
#Grouping (Core Corporate Skill) - Group by Department and calculate the average score per department. -
#Group by Quarter and find the maximum score achieved in each quarter. Business Context -
#Filtering helps HR identify exceptional performers and focus on specific departments. -
#Sorting creates clear performance rankings, useful for promotions or recognition programs. -
#Grouping reveals departmental strengths and quarterly performance trends, guiding training and resource allocation.

import pandas as pd
import numpy as np

# Create a dummy Dataset1.csv for demonstration
data = {
    'Employee': [f'Employee_{i}' for i in range(1, 101)],
    'Department': np.random.choice(['Sales', 'HR', 'IT', 'Finance'], 100),
    'Quarter': np.random.choice(['Q1', 'Q2', 'Q3', 'Q4'], 100),
    'Score': np.random.randint(60, 100, 100)
}
dummy_df = pd.DataFrame(data)
dummy_df.to_csv('Dataset1.csv', index=False)

# 1️⃣ Load Dataset
df = pd.read_csv("Dataset1.csv")

# -----------------------------
# 🔄 DATA CLEANING / TRANSFORMATION
# -----------------------------

# Remove extra spaces in column names (important transformation step)
df.columns = df.columns.str.strip()

# Ensure Score column is numeric
df["Score"] = pd.to_numeric(df["Score"], errors="coerce")

# Fill missing scores with department average (Smart Transformation)
df["Score"] = df.groupby("Department")["Score"].transform(
    lambda x: x.fillna(x.mean())
)

# -----------------------------
# 🔎 FILTERING (Core Skill)
# -----------------------------

# Exceptional performers
exceptional = df[df["Score"] > 90]

# Sales department only
sales_only = df[df["Department"] == "Sales"]

# -----------------------------
# 📊 SORTING (Power Moment)
# -----------------------------

# Rank employees by Score (descending)
ranked = df.sort_values("Score", ascending=False)

# Department-wise ranking
dept_rank = df.sort_values(["Department", "Score"], ascending=[True, False])

# -----------------------------
# 📈 GROUPING (Core Skill)
# -----------------------------

# Average score per department
avg_dept = df.groupby("Department")["Score"].mean()

# Maximum score per quarter
max_quarter = df.groupby("Quarter")["Score"].max()

# -----------------------------
# Print Results
# -----------------------------
print("\nExceptional Performers:\n", exceptional)
print("\nSales Department:\n", sales_only)
print("\nRanked Employees:\n", ranked)
print("\nDepartment-wise Ranking:\n", dept_rank)
print("\nAverage Score per Department:\n", avg_dept)
print("\nMax Score per Quarter:\n", max_quarter)
# Out:
# Exceptional Performers:
#         Employee Department Quarter  Score
# 0    Employee_1      Sales      Q2     99
# 8    Employee_9         HR      Q2     98
# 14  Employee_15    Finance      Q2     93
# 22  Employee_23      Sales      Q4     93
# 23  Employee_24      Sales      Q2     98
# 31  Employee_32         HR      Q4     99
# 33  Employee_34    Finance      Q3     95
# 34  Employee_35         IT      Q1     98
# 38  Employee_39         HR      Q2     93
# 42  Employee_43      Sales      Q4     99
# 43  Employee_44      Sales      Q4     94
# 66  Employee_67         IT      Q2     92
# 67  Employee_68    Finance      Q3     96
# 69  Employee_70         HR      Q2     91
# 77  Employee_78    Finance      Q2     99
# 80  Employee_81    Finance      Q4     91
# 83  Employee_84      Sales      Q3     98
# 88  Employee_89    Finance      Q2     95
# 93  Employee_94         IT      Q3     99
# 96  Employee_97      Sales      Q1     94
#
# Sales Department:
#          Employee Department Quarter  Score
# 0     Employee_1      Sales      Q2     99
# 17   Employee_18      Sales      Q1     75
# 18   Employee_19      Sales      Q2     65
# 22   Employee_23      Sales      Q4     93
# 23   Employee_24      Sales      Q2     98
# 26   Employee_27      Sales      Q1     63
# 28   Employee_29      Sales      Q4     75
# 41   Employee_42      Sales      Q2     90
# 42   Employee_43      Sales      Q4     99
# 43   Employee_44      Sales      Q4     94
# 45   Employee_46      Sales      Q3     70
# 48   Employee_49      Sales      Q1     64
# 52   Employee_53      Sales      Q1     72
# 64   Employee_65      Sales      Q1     87
# 65   Employee_66      Sales      Q2     84
# 74   Employee_75      Sales      Q1     72
# 76   Employee_77      Sales      Q3     80
# 83   Employee_84      Sales      Q3     98
# 91   Employee_92      Sales      Q2     63
# 96   Employee_97      Sales      Q1     94
# 97   Employee_98      Sales      Q3     72
# 99  Employee_100      Sales      Q3     70
#
# Ranked Employees:
#         Employee Department Quarter  Score
# 0    Employee_1      Sales      Q2     99
# 31  Employee_32         HR      Q4     99
# 77  Employee_78    Finance      Q2     99
# 42  Employee_43      Sales      Q4     99
# 93  Employee_94         IT      Q3     99
# ..          ...        ...     ...    ...
# 46  Employee_47         HR      Q1     62
# 86  Employee_87    Finance      Q4     62
# 85  Employee_86         HR      Q4     61
# 63  Employee_64         HR      Q3     60
# 53  Employee_54         HR      Q1     60
#
# [100 rows x 4 columns]
#
# Department-wise Ranking:
#          Employee Department Quarter  Score
# 77   Employee_78    Finance      Q2     99
# 67   Employee_68    Finance      Q3     96
# 33   Employee_34    Finance      Q3     95
# 88   Employee_89    Finance      Q2     95
# 14   Employee_15    Finance      Q2     93
# ..           ...        ...     ...    ...
# 99  Employee_100      Sales      Q3     70
# 18   Employee_19      Sales      Q2     65
# 48   Employee_49      Sales      Q1     64
# 26   Employee_27      Sales      Q1     63
# 91   Employee_92      Sales      Q2     63
#
# [100 rows x 4 columns]
#
# Average Score per Department:
#  Department
# Finance    80.772727
# HR         76.483871
# IT         81.160000
# Sales      80.772727
# Name: Score, dtype: float64
#
# Max Score per Quarter:
#  Quarter
# Q1    98
# Q2    99
# Q3    99
# Q4    99
# Name: Score, dtype: int64
