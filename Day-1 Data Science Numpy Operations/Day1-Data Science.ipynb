# %%
#Import numpy
import numpy as np

# %%
#create a numpy array
arr = np.array([10,20,30,40,50])
arr
# Out:
# array([10, 20, 30, 40, 50])

# %%
#Simple calculation with numpy
arr*2
# Out:
# array([ 20,  40,  60,  80, 100])

# %%
#find Sum
arr.sum()
# Out:
# np.int64(150)

# %%
#Find mean
arr.mean()
# Out:
# np.float64(30.0)

# %%
#Find maximum value
arr.max()
# Out:
# np.int64(50)

# %%
#2d Array (Very important for ML)
arr1=np.array([[1,2,3],[4,5,6]])
arr1
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
#Notebook-based Data Exploration
import pandas as pd # Importing pandas library and giving it a short name 'pd'

df=pd.read_csv("sample_data1.csv") #Reads the csv file ans stores it in a dataframe called df
df.head()
#Displays the first 5 rows of the dataset (Default=5 rows)
# Used to quickly check how data looks
# Out:
#    Employee_ID Department Region  Salary  Experience_Years  \
# 0         1001      Sales  North   45000                 2
# 1         1002  Marketing  South   52000                 3
# 2         1003      Sales   East   47000                 4
# 3         1004         HR   West   40000                 1
# 4         1005         IT  North   60000                 5
#
#    Performance_Rating  Monthly_Sales
# 0                 4.0       120000.0
# 1                 3.0        98000.0
# 2                 5.0       150000.0
# 3                 3.0            0.0
# 4                 4.0            0.0

# %%
#Notebook-based Data Exploration
import pandas as pd # Importing pandas library and giving it a short name 'pd'

df=pd.read_csv("sample_data1.csv") #Reads the csv file ans stores it in a dataframe called df
df.shape
# Returns the size of dataset in (rows, columns)
# Example: (100, 5) → 100 rows and 5 columns
# Out:
# (15, 7)

# %%
#Notebook-based Data Exploration
import pandas as pd # Importing pandas library and giving it a short name 'pd'

df=pd.read_csv("sample_data1.csv") #Reads the csv file ans stores it in a dataframe called df
df.info() # Gives summary of dataset:
          # - Column names
          # - Non-null values count
          # - Data types of each column
          # - Memory usage
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 7 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Employee_ID         15 non-null     int64
#  1   Department          15 non-null     object
#  2   Region              15 non-null     object
#  3   Salary              15 non-null     int64
#  4   Experience_Years    15 non-null     int64
#  5   Performance_Rating  14 non-null     float64
#  6   Monthly_Sales       14 non-null     float64
# dtypes: float64(2), int64(3), object(2)
# memory usage: 972.0+ bytes

# %%
#Notebook-based Data Exploration
import pandas as pd # Importing pandas library and giving it a short name 'pd'

df=pd.read_csv("sample_data1.csv") #Reads the csv file ans stores it in a dataframe called df

df.describe()
# Provides statistical summary of numerical columns:
# - count
# - mean
# - standard deviation
# - minimum value
# - 25%, 50%, 75% percentiles
# - maximum value
# Out:
#        Employee_ID        Salary  Experience_Years  Performance_Rating  \
# count    15.000000     15.000000         15.000000           14.000000
# mean   1008.000000  49666.666667          3.200000            3.785714
# std       4.472136   7158.079019          1.373213            0.892582
# min    1001.000000  39000.000000          1.000000            2.000000
# 25%    1004.500000  45500.000000          2.000000            3.000000
# 50%    1008.000000  49000.000000          3.000000            4.000000
# 75%    1011.500000  52500.000000          4.000000            4.000000
# max    1015.000000  62000.000000          6.000000            5.000000
#
#        Monthly_Sales
# count      14.000000
# mean    76928.571429
# std     62039.025293
# min         0.000000
# 25%         0.000000
# 50%     95000.000000
# 75%    128750.000000
# max    150000.000000

# %%
#Notebook-based Data Exploration
import pandas as pd # Importing pandas library and giving it a short name 'pd'

df=pd.read_csv("sample_data1.csv") #Reads the csv file ans stores it in a dataframe called df

df.isnull().sum()
# Checks missing values in each column
# isnull() → True where value is missing
# sum() → counts total missing values column-wise
# Out:
# Employee_ID           0
# Department            0
# Region                0
# Salary                0
# Experience_Years      0
# Performance_Rating    1
# Monthly_Sales         1
# dtype: int64

# %%
# Question which needs to answered for the sales data
# No of Rows
# Missing columns values
# Print the average salary of Employees
# Print the department which has max no of Employees
import pandas as pd

df=pd.read_csv("sample_data1.csv")
df.shape # 15 as row and 7 as column #To get no of rows
# Out:
# (15, 7)

# %%
import pandas as pd

df=pd.read_csv("sample_data1.csv")
df.isnull().sum() #Returns the column has missing values
# Performance reating and monthly sales has missing values in them as 1,1
# Out:
# Employee_ID           0
# Department            0
# Region                0
# Salary                0
# Experience_Years      0
# Performance_Rating    1
# Monthly_Sales         1
# dtype: int64

# %%
import pandas as pd

df=pd.read_csv("sample_data1.csv")
df.Department.max()  #Will return the department which has max employees
# Out:
# 'Sales'

# %%
import pandas as pd

df=pd.read_csv("sample_data1.csv")
df.Salary.mean() # will return the average salary np.float64(49666.666666666664)
# Out:
# np.float64(49666.666666666664)
