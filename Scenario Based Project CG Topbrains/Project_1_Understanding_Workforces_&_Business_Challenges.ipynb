# %%
# Question
# 1
# NewDatabasescenario
# Description
#  Problem Statement Scenario: Understanding Workforce & Business Challenges

# # A company is facing multiple challenges across different domains:

# Employee Attrition: HR suspects that certain departments are losing employees faster than others, and they want to identify patterns.
# Sales Data: The sales team wants to understand which products and regions are performing best, and whether missing data is affecting their reporting.
# Telecom Churn: The telecom division is worried about losing customers and wants to explore churn-related factors.
# As a Data Scientist, you are tasked with conducting initial exploratory analysis on one of these datasets using Jupyter Notebook. Your goal is to provide quick insights that management can act upon.https://github.com/himanshusar123/Datasets


import pandas as pd

telecom = pd.read_csv("/Users/ayush/Desktop/project/telecom_churn - Sheet1.csv")

telecom.head()
telecom.shape
telecom.info()
telecom.describe()
telecom.isnull().sum()
telecom.dropna(inplace=True)
telecom.rename(columns={"Customer_ID": "Cust_ID"}, inplace=True)
print(telecom)

telecom.fillna(telecom.mean(numeric_only=True), inplace=True)
print(telecom)

sorted_customers = telecom.sort_values(by="Tenure_Months")
print(sorted_customers)
